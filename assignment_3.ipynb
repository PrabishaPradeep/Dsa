# %% [markdown]
# <a href="https://colab.research.google.com/github/PrabishaPradeep/Dsa/blob/main/assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ASSIGNMENT ON MEASURES OF CENTRAL TENDANCY AND DISPERSION**
#
# ---

# %% [markdown]
# An Institution wishes to find out their student’s ability in mathematics, reading and writing skills. The Institution wants to do an exploratory study to check the following information.

# %% [markdown]
# let us start by importing necessary libraries ,then read the dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("/content/StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # **1.   Find out how many males and females participated in the test.**

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
sns.countplot(x='gender',data=df)
plt.show()

# %% [markdown]
# There are 518 females and 482 males participated in the test.

# %% [markdown]
# # **2.   What do you think about the students' parental level of education?**

# %%
parents=df["parental level of education"].value_counts()
parents
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
plt.pie(parents,labels=parents.index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# It can be seen  that parents studied in some college is highest and parents with master's degree is too low.Most of the parents, i.e. 37.5 % (19.6 % + 17.9 %) are completed some type of high school education. Whereas 22.6 % studied some type of college education. Also 22.2 % have associate's degree. Only 11.8 % done bachelor's degree. And a very small percentage (5.9 %) is with master's degree.

# %% [markdown]
# # **3.   Who scores the most on average for math, reading and writing based on gender**

# %%
df.groupby('gender')[['math score','reading score','writing score']].mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
df.groupby('gender')[['math score','reading score','writing score']].mean().plot(kind='bar')
plt.title('Math, Reading and Writing Score Averages based on Gender')
plt.ylabel('average')
plt.show()

# %% [markdown]
# females scores most on average in both reading and writing whereas male students scores most on average in maths.

# %% [markdown]
# # **4.   Who scores the most on average for math, reading and writing based on Test preparation course**

# %%
df.groupby('test preparation course')[['math score','reading score','writing score']].mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
df.groupby('test preparation course')[['math score','reading score','writing score']].mean().plot(kind='bar')
plt.title('Math, Reading and Writing Score Averages based on Test Preparation Course')
plt.ylabel('average')
plt.show()

# %% [markdown]
# It seems that students that completed the test preparation course score higher than those that did not.

# %% [markdown]
# # **5. What do you think about the scoring variation for math, reading and writing based on Gender**

# %%
df.groupby('gender')[['math score','reading score','writing score']].agg(['max','min','var'])
# Out:
#        math score                 reading score                 writing score  \
#               max min         var           max min         var           max
# gender
# female        100   0  256.958593           100  17  207.677438           100
# male          100  27  211.889097           100  23  200.211010           100
#
#
#        min         var
# gender
# female  10  220.369327
# male    15  202.413924

# %% [markdown]
# 1. scores of females in maths varies from 0 to 100 and scores of males vaies from 27 to 100 .
# 2. female have  attained  scores ranging from 17 to 100 and males have attained a score ranging from 23 to 100 in reading. whereas in writing females scored on the range of 10 to 100 and males scored on the range of 15 to 100.
# 3. females shows higher scoring variation for math, reading and writing as compared to males. Females have lower minimum scores in all subjects compared to males, suggesting that there are more low-performing female students in the class.

# %% [markdown]
# # **5. What do you think about the scoring variation for math, reading and writing based on Test preparation course**

# %%
df.groupby('test preparation course')[['math score','reading score','writing score']].agg(['max','min','var'])
# Out:
#                         math score                 reading score      \
#                                max min         var           max min
# test preparation course
# completed                      100  23  210.884027           100  37
# none                           100   0  246.668662           100  17
#
#                                     writing score
#                                 var           max min         var
# test preparation course
# completed                183.265864           100  36  175.202612
# none                     213.419851           100  10  226.251739

# %% [markdown]
# 1. Students who completed the test preparation course have a higher minimum score (23) compared to those who did not complete it (0).
# 2. the minimum reading score is higher for students who completed the test preparation course (37) compared to those who did not (17)
# 3. minimum writing score is higher for students who completed the test preparation course (36) compared to those who did not (10) .

# %% [markdown]
# students who have completed the test preparation course shows smaller variation in math, reading and writing as compared to those who have not.This suggests that test preparation has a positive impact .

# %% [markdown]
# # **6. The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management to achieve this.**

# %% [markdown]
# Top 25% of students are basically the students who scored third quartile (75th percentage) of score or more.

# %%
maths_threshold =df["math score"].quantile(0.75)
maths_threshold
# Out:
# 77.0

# %% [markdown]
# now let's Find the students who scored maths_threshold score = 77 or more and sort them in descending order

# %%
top_25_percent_maths_students=df[df['math score']>=77].sort_values(by='math score',ascending=False)
top_25_percent_maths_students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 998    male        group E          associate's degree  free/reduced
# 997    male        group D                some college      standard
# 996    male        group A                some college      standard
# 517  female        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 854    male        group D            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 856    male        group E            some high school      standard
# 415  female        group B             master's degree  free/reduced
# 414  female        group A                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# these are the students selected for bonus points
